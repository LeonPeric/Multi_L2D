# %%
import matplotlib.pyplot as plt
import json
import numpy as np

# %%
with open("logs_ova_42_0.08_expert4.json") as f:
    logs = json.load(f)

# %%
logs[0]
# Out:
# {'coverage': 78.36538461538461,
#  'system_accuracy': 84.91586538461539,
#  'expert_accuracy': 79.72220007716665,
#  'classifier_accuracy': 86.34968994057937,
#  'alone_classifier': 86.35817307692308,
#  'validation_loss': 2.1980678118192234,
#  'n_experts': 1,
#  'expert_0': 79.72220007716665,
#  'train_loss': 2.873619021475315}

# %%
train_loss = []
validation_loss = []
for item in logs:
    train_loss.append(item["train_loss"])
    validation_loss.append(item["validation_loss"])

# %%
plt.plot(train_loss)
plt.plot(validation_loss)
